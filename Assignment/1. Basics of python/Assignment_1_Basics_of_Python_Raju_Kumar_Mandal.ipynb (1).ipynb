# %% [markdown]
# #### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %% [markdown]
# number=int(input("Enter Number"))
# is_prime=True
# for x in range(2,number):
#     if number%x==0:
#         is_prime=False
# if is_prime:
#     print("It is a Prime Number")
# else:
#     print("It is not Prime Number")

# %% [markdown]
# #### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
a=random.randint(1,10)
b=random.randint(1,10)
product=int(input(f"Enter The Product {a} * {b} "))
if product==(a*b):
    print("Wow you are correct")
else:
    print("Not corret")
# Out:
# Enter The Product 1 * 7  6
# Not corret

# %% [markdown]
# #### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for x in range(100,200):
    print(f"Squares of {x} id {x*x}")
# Out:
# Squares of 100 id 10000
# Squares of 101 id 10201
# Squares of 102 id 10404
# Squares of 103 id 10609
# Squares of 104 id 10816
# Squares of 105 id 11025
# Squares of 106 id 11236
# Squares of 107 id 11449
# Squares of 108 id 11664
# Squares of 109 id 11881
# Squares of 110 id 12100
# Squares of 111 id 12321
# Squares of 112 id 12544
# Squares of 113 id 12769
# Squares of 114 id 12996
# Squares of 115 id 13225
# Squares of 116 id 13456
# Squares of 117 id 13689
# Squares of 118 id 13924
# Squares of 119 id 14161
# Squares of 120 id 14400
# Squares of 121 id 14641
# Squares of 122 id 14884
# Squares of 123 id 15129
# Squares of 124 id 15376
# Squares of 125 id 15625
# Squares of 126 id 15876
# Squares of 127 id 16129
# Squares of 128 id 16384
# Squares of 129 id 16641
# Squares of 130 id 16900
# Squares of 131 id 17161
# Squares of 132 id 17424
# Squares of 133 id 17689
# Squares of 134 id 17956
# Squares of 135 id 18225
# Squares of 136 id 18496
# Squares of 137 id 18769
# Squares of 138 id 19044
# Squares of 139 id 19321
# Squares of 140 id 19600
# Squares of 141 id 19881
# Squares of 142 id 20164
# Squares of 143 id 20449
# Squares of 144 id 20736
# Squares of 145 id 21025
# Squares of 146 id 21316
# Squares of 147 id 21609
# Squares of 148 id 21904
# Squares of 149 id 22201
# Squares of 150 id 22500
# Squares of 151 id 22801
# Squares of 152 id 23104
# Squares of 153 id 23409
# Squares of 154 id 23716
# Squares of 155 id 24025
# Squares of 156 id 24336
# Squares of 157 id 24649
# Squares of 158 id 24964
# Squares of 159 id 25281
# Squares of 160 id 25600
# Squares of 161 id 25921
# Squares of 162 id 26244
# Squares of 163 id 26569
# Squares of 164 id 26896
# Squares of 165 id 27225
# Squares of 166 id 27556
# Squares of 167 id 27889
# Squares of 168 id 28224
# Squares of 169 id 28561
# Squares of 170 id 28900
# Squares of 171 id 29241
# Squares of 172 id 29584
# Squares of 173 id 29929
# Squares of 174 id 30276
# Squares of 175 id 30625
# Squares of 176 id 30976
# Squares of 177 id 31329
# Squares of 178 id 31684
# Squares of 179 id 32041
# Squares of 180 id 32400
# Squares of 181 id 32761
# Squares of 182 id 33124
# Squares of 183 id 33489
# Squares of 184 id 33856
# Squares of 185 id 34225
# Squares of 186 id 34596
# Squares of 187 id 34969
# Squares of 188 id 35344
# Squares of 189 id 35721
# Squares of 190 id 36100
# Squares of 191 id 36481
# Squares of 192 id 36864
# Squares of 193 id 37249
# Squares of 194 id 37636
# Squares of 195 id 38025
# Squares of 196 id 38416
# Squares of 197 id 38809
# Squares of 198 id 39204
# Squares of 199 id 39601

# %% [markdown]
#  #### ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
day=4
test=3;
madicine=2400
total=(day*2000)+(1500)+(madicine)+(test*300)
if total>=10000:
    total=(total/100)*90
print(f"Your bill {total}")
# Out:
# Your bill 11520.0
