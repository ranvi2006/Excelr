# %% [markdown]
# ###### 1.	Create a list of 5 integers. Perform and print the result of the following operations: append, extend, insert, remove, pop, clear, index, count, sort, and reverse.

# %%
list=[2,5,4,9,3]
list
# Out:
# [2, 5, 4, 9, 3]

# %%
# Append Function 
# This function is use to add element at the last index of the list
list.append(6)
# if you pass [3,4,,6,7] in paramiter then it will add at last as one list
list
# Out:
# [2, 5, 4, 9, 3, 6]

# %%
# Extend Function 
# This function is use to add multiple element of by at last index
list.extend([78,45])
# if you pass [3,4,,6,7] in paramiter then it will add at last one by one
list
# Out:
# [2, 5, 4, 9, 3, 6, 78, 45]

# %%
#  Insert Function
# It is use to add element at any specify place
list.insert(3,"Raju")
list
# Out:
# [2, 5, 4, 'Raju', 9, 3, 6, 78, 45]

# %%
list.remove(3) # This is use to remove the matiching element form the list which gives as remove function paramiter
list
# Out:
# [2, 5, 4, 'Raju', 9, 6, 78, 45]

# %%
# Pop Function is used to remove the last element form the list
list.pop()
list
# Out:
# [2, 5, 4, 'Raju', 9, 6, 78]

# %%
# index Function is use to get the indext of the element
list.index("Raju")
# Out:
# 3

# %%
# Count function is used to count the same element in the list which i passes in the paramiter
list.count("Raju")
# Out:
# 1

# %%
# Sort Function is used to sort the list in assending or decending order
list.remove("Raju")
list.sort()
list
# Out:
# [2, 4, 5, 6, 9, 78]

# %%
# Reverse Function is used to reverse the full list 
list.reverse()
list
# Out:
# [78, 9, 6, 5, 4, 2]

# %%
# Clear Function is use to clear all the data from the list
list.clear()
list
# Out:
# []

# %% [markdown]
# #### 2.	Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why.

# %%
tup=("Raju","Ranjan","Akash")
# tup[1]="Krishna" // this line giving this error 'tuple' object does not support item assignment
# because tupule is immutable so we can not make any changes in the tuple |

# %% [markdown]
#  #### 3.	Create a set of integers with some duplicate values. Print the set and explain the output.

# %%
set={2,5,9,4,6,5,9}
set  
# {2, 4, 5, 6, 9} it is showing like this beacuse set it created for storing only uniqe value not duplicate Value
# Out:
# {2, 4, 5, 6, 9}

# %% [markdown]
#  #### 4.	Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary.

# %%
dict={
    "Name":"Raju Kumar Mandal",
    "age":21,
    "city":"Suriya"
}
print(dict)
dict["age"]=22  # it replace age value 21 to 22
dict["email"]="rajurk2002@gmail.com" # email key is not present in the dict so it will create new key as email and assign the value
dict
# Out:
# {'Name': 'Raju Kumar Mandal', 'age': 21, 'city': 'Suriya'}
# {'Name': 'Raju Kumar Mandal',
#  'age': 22,
#  'city': 'Suriya',
#  'email': 'rajurk2002@gmail.com'}

# %% [markdown]
#  #### 5.	 Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message.

# %%
age=int(input("Enter your age"))
if age>=18:
    print("You are Eligible To Vote")
else:
    print("You are not Eligible To Vote")

# %% [markdown]
# #### 6.	Given a 'marks' variable, print the grade:
# - 90 and above: 'A'
# - 75–89: 'B'
# - 50–74: 'C'
# - Below 50: 'Fail'

# %%
marks=int(input("Enter your marks"))
if marks>=90:
    print("You Got Grade A");
elif marks>=75 and marks<=89:
    print("You Got Grade B");
elif  marks>=50 and marks<=74:
    print("You Got Grade C");
else:
    print("Fail, Batter luck next time");

# %% [markdown]
# #### 7.	Given a number, check if it's positive, and if it is also even. If not positive, print if it's zero or negative.

# %%
number=int(input("Enter number"))
if number>0:
    if number%2==0:
        print("Number is Positive and Even")
    else:
        print("Number is Positive and Odd")
else:
    print("0")

# %% [markdown]
# ## Section B: Numpy

# %%
## We are using this package to make matematical calculation more easy

import numpy as np

# %%
# - A scalar using np.array(5)
arr=np.array(5)  # it is 0 dimention array

# %%
# - A 1D array with values 1 to 5
arr1=np.array([1,2,3,4,5])
arr1

# %%
# - A 2D array (2x3) with values from 10 to 60 in steps of 10
arr2=np.arange(10,61,10).reshape(2,3)
arr2

# %%
# 9.	Generate a 4x4 Numpy array of random integers between 0 and 100 using np.random.randint().
arr3=np.random.randint(0,100,size=(4,4))
arr3

# %%
# 10.	Create a 2D numpy array of shape (3x3). Convert it into a pandas DataFrame and add column names: 'A', 'B', 'C'.
arr4=np.array([[3,6,9],
              [12,15,18],
              [2,23,25]])
arr4
import pandas as pd
df=pd.DataFrame(arr4,columns=["A","B","C"])
df

# %% [markdown]
# ## Section C: Exploring Pandas

# %% [markdown]
#  #### 11.	Create a small DataFrame manually with 10 rows and columns: 'Name', 'Age', 'City', and 'Salary'. Then:
# - Use .info(), .describe()
# - Select 'Name' and 'City' columns
# - Drop 'City' column
# - Fill any missing values in 'Salary' column with the mean
# - Remove any duplicate rows

# %%
data=np.array([["Ram",21,"Suriya",12000],
["Ranjan",20,"jharkhand",12000],
["Raju",26,"Suriya",12400],
["Akash",18,"giridih",12200],
["aku",16,"giridih",12900],
["kaju",12,"Suriya",11000],
["parveen",81,"banglore",26000],
["Kajal",41,"hydrabad",82000],
["anju",11,"panjab",12090],
["Vikash",31,None,12700]])
columns=["Name","Age","City","Salary"]

# %%
df1=pd.DataFrame(data,columns=columns)
df1.info()

# %%
df1.describe()

# %%
df1[["Name","City"]]

# %%
df1.drop(["City"],axis=1)

# %%
df1.isna().sum()

# %%
city_mode=df1["City"].mode()[0]
city_mode

# %%
df1.fillna({"City" :city_mode})

# %%
df1.duplicated().sum()

# %%
# There ane no dupilate
