# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2
# this is <font color="blue"> bule </font> text

# %% [markdown]
# ### heading 3

# %% [markdown]
# #### heading 4

# %% [markdown]
# ##### Heading 5

# %% [markdown]
# ###### Heading 6

# %%
# this is a comment
print("hello")
# Out:
# hello

# %%
# Integer
x=10
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 10

# %%
# float
x=10.6
type(x)
# Out:
# float

# %%
# Boolean 
x=True
type(x)
# Out:
# bool

# %%
print(x)
# Out:
# True

# %% [markdown]
# #### airthmatic operation

# %%
x=10
y=3
x+y
# Out:
# 13

# %%
# substraction
x-y
# Out:
# 7

# %%
# multiplication
x*y
# Out:
# 30

# %%
# devision
x/y
# Out:
# 3.3333333333333335

# %%
# module
x%y
# Out:
# 1
