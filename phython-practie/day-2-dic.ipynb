# %% [markdown]
# ### Dictionary
# #### It Stores value in ket Pair
# d1={name:"Raju Kumar",
# age:21,
# course:"data science"}

# %%
dic={"name":"Raju Kumar",
"age":21,
"course":"data science"}

# %%
print(dic);
# Out:
# {'name': 'Raju Kumar', 'age': 21, 'course': 'data science'}

# %%
print(dict["name"]);
print(len(dic["name"]));
print(type(dic));
print(type(dic["name"]));
# Out:
# dict['name']
# 10
# <class 'dict'>
# <class 'str'>

# %%
marks={"raju":[56,65,76,77],
      "ranjan":[79,87,76,98],
       "jon":[65,76,76,43]
      };
marks
# Out:
# {'raju': [56, 65, 76, 77], 'ranjan': [79, 87, 76, 98], 'jon': [65, 76, 76, 43]}

# %%
marks2=dict( raju=[56,65,76,77],
      ranjan=[79,87,76,98],
       jon=[65,76,76,43]
);
marks2
# Out:
# {'raju': [56, 65, 76, 77], 'ranjan': [79, 87, 76, 98], 'jon': [65, 76, 76, 43]}

# %%
d1={
    1:"one",
    2:"two",
    3:"three"   
}
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d2=dict.fromkeys(['raju','ranjan','akash'],)
d2
# Out:
# {'raju': None, 'ranjan': None, 'akash': None}

# %%
d3=dict.fromkeys(['raju','ranjan','akash'],20)
d3
# Out:
# {'raju': 20, 'ranjan': 20, 'akash': 20}

# %%
l1=["Raju","Ram","Akash","Ritik","Rohit"]
l2=[78,98,89,90,95];
d4=zip(l1,l1);
d4

# %%
for x in zip(l1,l2):
    print(x)
# Out:
# ('Raju', 78)
# ('Ram', 98)
# ('Akash', 89)
# ('Ritik', 90)
# ('Rohit', 95)

# %%
states=["TN","AP","UP","MP","JH"];
capital=["Chennai","Amaravathy","Luknow","Bhopal","Jharkhand"];
d5=zip(states,capital);

# %%
for x in zip(states,capital):
    print(x);
# Out:
# ('TN', 'Chennai')
# ('AP', 'Amaravathy')
# ('UP', 'Luknow')
# ('MP', 'Bhopal')
# ('JH', 'Jharkhand')

# %%
w
