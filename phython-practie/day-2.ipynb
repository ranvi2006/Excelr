# %% [markdown]
# ## Logical Operators

# %%
x=True
y=False

# %%
x & y
# Out:
# False

# %%
x or b
# Out:
# True

# %%
not x
# Out:
# False

# %%
not y
# Out:
# True

# %% [markdown]
# # non-primitive data type
# ##  sequesnce -->{List , Tuple , String}

# %% [markdown]
# ### List Declaration

# %%
lst=[25,45,65,78,90]

# %%
lst
# Out:
# [25, 45, 65, 78, 90]

# %%
type(lst)
# Out:
# list

# %% [markdown]
# ### tuple Declaration

# %%
tup1=(25,45,65,78,90)

# %%
tup1
# Out:
# (25, 45, 65, 78, 90)

# %%
type(tup1)
# Out:
# tuple

# %%
### String

# %%
name="Raju Kumar Mandal"
spname=''' Hello World !
How are you  '''
print(spname)
print(name)
# Out:
#  Hello World !
# How are you
# Raju Kumar Mandal

# %%
type(name)
# Out:
# str

# %% [markdown]
# Position Indexing - Accessing Elements using index

# %%
name[3]
# Out:
# 'u'

# %%
lst[4]
# Out:
# 90

# %%
tup1[3]
# Out:
# 78

# %%
tup1[-1]
# Out:
# 90

# %% [markdown]
# #### Sliceing a Sequence

# %%
lst[1:4]
# Out:
# [45, 65, 78]

# %%
lst[0:]
# Out:
# [25, 45, 65, 78, 90]

# %%
lst[2:]
# Out:
# [65, 78, 90]

# %% [markdown]
# #### Itration

# %%
for x in lst:
    print(x)
    print("hii")
# Out:
# 25
# hii
# 45
# hii
# 65
# hii
# 78
# hii
# 90
# hii

# %%
for x in tup1:
    print(x)
print("hii")
# Out:
# 25
# 45
# 65
# 78
# 90
# hii

# %%
for x in name:
    print(x)
# Out:
# R
# a
# j
# u
#
# K
# u
# m
# a
# r
#
# M
# a
# n
# d
# a
# l

# %%
mixed_lst=[10,6.78,True,[23,45,67],(1,2,3),"Apple"]

# %%
for lst in mixed_lst:
    print(lst)
# Out:
# 10
# 6.78
# True
# [23, 45, 67]
# (1, 2, 3)
# Apple

# %%
len(mixed_lst)
# Out:
# 6

# %%
min(mixed_lst[3])
# Out:
# 23

# %%
sum(mixed_lst[4])
# Out:
# 6

# %%
sum(mixed_lst[4])/len(mixed_lst)
# Out:
# 1.0

# %%
'u' in name
# Out:
# True
