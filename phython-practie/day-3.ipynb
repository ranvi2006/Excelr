# %%
lst=[23,34,53,5456,65,23,12,76];

# %%
lst
# Out:
# [23, 34, 53, 5456, 65, 23, 12, 76]

# %% [markdown]
# ### sort

# %%
lst.sort()
print(lst)
# Out:
# [12, 23, 23, 34, 53, 65, 76, 5456]

# %%
lst.sort(reverse=True);
print(lst)
# Out:
# [5456, 76, 65, 53, 34, 23, 23, 12]

# %%
mixed_lst=[10,6.78,True,[23,45,67],(1,2,3),"Apple"];
shop_lst=["Apple","Jam","Notebook","Papper","Rice","Shampoo","soap","suger","Ball"];

# %%
print(mixed_lst);
print(shop_lst);
# Out:
# [10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple']
# ['Apple', 'Jam', 'Notebook', 'Papper', 'Rice', 'Shampoo', 'soap', 'suger', 'Ball']

# %%
shop_lst.sort();
print(shop_lst);
shop_lst.sort(reverse=True);
print(shop_lst);
# Out:
# ['Apple', 'Ball', 'Jam', 'Notebook', 'Papper', 'Rice', 'Shampoo', 'soap', 'suger']
# ['suger', 'soap', 'Shampoo', 'Rice', 'Papper', 'Notebook', 'Jam', 'Ball', 'Apple']

# %% [markdown]
# #### Count the number of occurance of an Elemnet

# %%
name_lst=["Raju Kumar Mandal","Ranjan Ram","Akash Sharma","Ritik Yadav"];
print(name_lst);
# Out:
# ['Raju Kumar Mandal', 'Ranjan Ram', 'Akash Sharma', 'Ritik Yadav']

# %%
print(name_lst.count("Raju Kumar Mandal"));
# Out:
# 1

# %%
number_lst=[2,3,2,34,2,3,45,45,65,5];
print(number_lst);
# Out:
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5]

# %%
print(number_lst.count(2));
# Out:
# 3

# %% [markdown]
# #### get the index of element

# %%
print(number_lst.index(65));
# Out:
# 8

# %% [markdown]
# #### Copy menthod

# %%
number_lst2=number_lst;
print(number_lst2);
# Out:
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5]

# %%
# number_lst2.append(89);
print(number_lst);
print(number_lst2);
# Out:
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5, 89]
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5, 89]

# %%
number_lst3=number_lst.copy();
print(number_lst3);
# Out:
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5, 89]

# %%
number_lst3.append(100);
print(number_lst);
print(number_lst3);
# Out:
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5, 89]
# [2, 3, 2, 34, 2, 3, 45, 45, 65, 5, 89, 100]

# %% [markdown]
# ### tuple method

# %%
name_tup=["Raju Kumar Mandal","Ranjan Ram","Akash Sharma","Ritik Yadav"];

# %%
# only you can allpy count and get index method only because tuble and immutable
print(name_tup);
# Out:
# ['Raju Kumar Mandal', 'Ranjan Ram', 'Akash Sharma', 'Ritik Yadav']

# %%
print(name_tup.count("Ranjan Ram"));
# Out:
# 1

# %%
print(len(name_tup));
# Out:
# 4

# %%
print(name_tup.index("Raju Kumar Mandal"));
# Out:
# 0

# %%
s1="hello world"

# %%
### print(s1.capitalize());
print(s1.title());
print(s1.upper());
print(s1.lower());
s2="    Raju    ";
print(s2.lstrip());
print(s2.rstrip());
print(s2.strip());

s3="This is big sentance for teasting split function";
print(s3.split());
s4="Apple,Grapes,Lemon,Melon,Mango";
print(s4.split(","));
fruit_lst=s4.split(",");
print(fruit_lst);
# Out:
# Hello World
# HELLO WORLD
# hello world
# Raju
#     Raju
# Raju
# ['This', 'is', 'big', 'sentance', 'for', 'teasting', 'split', 'function']
# ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']
# ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']

# %%
','.join(fruit_lst);
ptint(fruit);
# Out:
# ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']
